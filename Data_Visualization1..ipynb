# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
# %matplotlib inline
import seaborn as sns
import yfinance as yf 
import mplfinance as mpf
import datetime

# %%
#write a function 
#function: grab ticker name the users input, startdate, enddate, adjusted close price, visualize in a line plot 
#function produced visualization stock performanance in the preriod of 5 years. 

def five_years_stock_performance(ticker):
    
   
    stockinfo = yf.download(ticker, start_date, end_date,period='5y')
    
    stockinfo['Adj Close'].plot(figsize=(10, 7))

# Define the label for the title of the figure
    plt.title("Adjusted Close Price of %s" % ticker, fontsize=16)
    plt.ylabel('Price', fontsize=14)
    plt.xlabel('Year', fontsize=14)

# Plot the grid lines
    plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)

# Show the plot
    plt.show()

# %%
five_years_stock_performance('AAPL')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
#write function to compare the stock with S&P 500 
#get s&p data 
#start_date = '2018-01-01'
#end_date = '2022-01-01'
ticker = '^GSPC'
stockinfo = yf.download(ticker,period = "5y",interval='3mo')
stockinfo.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2017-12-01  2683.729980  2872.870117  2532.689941  2713.830078  2713.830078
# 2018-03-01  2715.219971  2801.899902  2553.800049  2705.270020  2705.270020
# 2018-06-01  2718.699951  2916.500000  2691.989990  2901.520020  2901.520020
# 2018-09-01  2896.959961  2940.909912  2603.540039  2760.169922  2760.169922
# 2018-12-01  2790.500000  2813.489990  2346.580078  2784.489990  2784.489990
#
#                   Volume
# Date
# 2017-12-01  157252660000
# 2018-03-01  223010410000
# 2018-06-01  212312730000
# 2018-09-01  235582510000
# 2018-12-01  235660820000

# %%
stockinfo.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
#calculate the return of S&P500 and the stock you want to plot 
stockinfo['snp500_return']=(stockinfo['Adj Close']/ stockinfo['Adj Close'].shift(1)) -1
stockinfo['snp500_return'].plot(kind='bar')
plt.bar()
plt.title("return of %s" % ticker, fontsize=16)
plt.ylabel('Price', fontsize=14)
plt.xlabel('Year', fontsize=14)

# Plot the grid lines
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)

# Show the plot
plt.show()
#show cl

# %%
stockinfo1 = yf.download(ticker, start_date, end_date,interval='3mo')
stockinfo1['ticker_return']=(stockinfo1['Adj Close']/ stockinfo1['Adj Close'].shift(1)) -1
#st4=pd.DataFrame(stockinfo1['ticker_return'])
stockinfo['snp500_return'].plot(kind='bar')
plt.title("return of %s" % ticker, fontsize=16)
plt.ylabel('Price', fontsize=14)
plt.xlabel('Year', fontsize=14)

# Plot the grid lines
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)

# Show the plot
plt.show()
#show cl

# %%
st2.columns
# Out:
# Index(['snp500_return'], dtype='object')

# %%
def returnof_SnP500_and_stock(ticker): 
   

    stockinfo1 = yf.download(ticker,period='5y',interval='3mo')
    stockinfo1['ticker_return']=(stockinfo1['Adj Close']/ stockinfo1['Adj Close'].shift(1)) -1
    
    st4=pd.DataFrame(stockinfo1['ticker_return'])
    
    plt.figure(figsize=(10,7))
#     plt.bar(stockinfo['snp500_return'], height= data=stockinfo, color = 'blue', width = 20, label='snp')
#     plt.bar(stockinfo1['ticker_return'], data=stockinfo1, color = 'green', width = 20, label='ticker return')
    stockinfo['snp500_return'].plot(kind='line',color='red')

    stockinfo1['ticker_return'].plot(kind='line',color='green')
    plt.title("comparison of %s" % ticker, fontsize=16)
    plt.ylabel('Percentage', fontsize=14)
    plt.xlabel('Year', fontsize=14)

# Plot the grid lines
    plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
    plt.ylim(-1, 1)
   

# Show the plot
    plt.show()
    
    
#set ylimit?

# %%
returnof_SnP500_and_stock('AMZN')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# # Testing for barchart

# %% [markdown]
# ##### Change function: returnof_SnP500_and_stock(ticker) into visualization function that return barchart instead of linechart.
